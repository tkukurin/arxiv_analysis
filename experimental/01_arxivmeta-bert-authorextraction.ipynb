# %% [markdown]
# # Author extraction
#
# The original ArXiv metadata authors were parsed using some combination of heuristics.
# Sometimes e.g. university and/or location becomes part of the name, usually as last item in a list.
# Some examples: '1 and 3', 'Iowa', 'Harvard University'.
#
# Maybe these can be manually fixed by using some heuristics, but maybe NER could be easy for ML approaches here.
# Proposal: use BERT pre-trained on CoNLL2013 to extract author names.

# %%
import os
import sys
if '..' not in sys.path:
    sys.path.append('..')
import logging
import _io

from arxiv_analysis import load

import itertools as it
import functools as ft
import collections as col
import typing as ty
import types

import json

import numpy as np
import scipy as sp
import pandas as pd

import torch
import spacy
import sklearn
import transformers as trf

from torch import nn
from torch import functional as F

import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
from collections import defaultdict
from typing import Callable, Union, List, Iterable


logging.basicConfig(
    format='[%(levelname)s] %(asctime)s %(message)s',
    datefmt='%Y-%m-%d %H:%M',
    level=logging.DEBUG)
L = logging.getLogger()


# %matplotlib inline


base = Path('/kaggle/input')
files = {f.name:list(f.glob('*')) 
         for f in base.glob('*')
         if f.is_dir()}

# !ls -l $base
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# total 4
# drwxr-xr-x 2 nobody nogroup 4096 Nov  8 09:31 arxiv

# %%
def trf_line(d: dict) -> dict:
    if 'cs.ai' in d['categories'].lower():
        return d
    return None

arxiv = load.ArxivDataset.load(
    loc=files['arxiv'][0],
    transform=trf_line,
    limit=100,
)

# %%
class AuthorClassifier:
    label_list = [
        "O",       # Outside of a named entity
        "B-MISC",  # Beginning of a miscellaneous entity right after another miscellaneous entity
        "I-MISC",  # Miscellaneous entity
        "B-PER",   # Beginning of a person's name right after another person's name
        "I-PER",   # Person's name 
        "B-ORG",   # Beginning of an organisation right after another organisation
        "I-ORG",   # Organisation
        "B-LOC",   # Beginning of a location right after another location
        "I-LOC"    # Location
    ]
    
    def __init__(self, pretrained, device='cpu'):
        self.device = device
        self.model = trf.AutoModelForTokenClassification.from_pretrained(pretrained).to(device)
        self.tokenizer = trf.AutoTokenizer.from_pretrained("bert-base-cased")
                                          
    def __call__(self, doc: spacy.tokens.Doc):
        '''Extract entities from the SpaCy document.
        '''
        inputs = self.tokenizer.encode(doc.text, return_tensors="pt")
        outputs, *_ = self.model(inputs.to(self.device))
        predictions, *_ = torch.argmax(outputs, dim=2).squeeze(-1).cpu()
        tokens = self._tokenize(doc.text)
        
        ents = list(self._align_ner2doc(doc, predictions, tokens))
        authors = list(self._extract_authors(doc, ents))
        
        return ents, authors
    
    def _tokenize(self, in_str):
        return self.tokenizer.convert_ids_to_tokens(self.tokenizer.encode(in_str))

    @classmethod
    def _align_ner2doc(cls, doc, predictions, tokens):
        def _match(text, tok_ix): # match spacy's tokens with tokenizer tokens
            text_ix = 0
            while tok_ix < len(tokens):
                tok = tokens[tok_ix].lstrip('#')
                if not text[text_ix:text_ix+len(tok)] == tok:
                    break
                tok_ix += 1
                text_ix += len(tok)
            return tok_ix
        
        i = 1
        for j, spacy_tok in enumerate(doc):
            # 1st wordpiece determines entire token
            pred_idx = predictions[i]
            label = cls.label_list[pred_idx]
            yield spacy.tokens.Span(doc, j, j+1, label=label)
            i = _match(spacy_tok.text, i)
            
    @staticmethod
    def _extract_authors(doc, ents: ty.List[spacy.tokens.Span]):
        def _contiguous_ner_end_idx(ents, j): # find contiguous span of *-PER labels
            while j < len(ents):
                if ents[j-1].end != ents[j].start or (
                        # hack: special-case hyphenated names.
                        ents[j].text is not '-' and
                        not ents[j].label_.endswith('PER')):
                    break
                j += 1
            return j
        
        i = 0
        while i < len(ents):
            j = i + 1
            if ents[i].label_.endswith('PER'):
                j = _contiguous_ner_end_idx(ents, j)
                yield spacy.tokens.Span(doc, i, j, label='author')
            i = j

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
clf = AuthorClassifier(
    pretrained="dbmdz/bert-large-cased-finetuned-conll03-english",
    device=device)
clf(arxiv.df.iloc[0].authors)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=998.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1334448817.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# ([T., Kosel, and, I., Grabec], [T. Kosel, I. Grabec])

# %%
# %%time

# either attach authors to the DataFrame
# or directly as an extension to the document
spacy.tokens.Doc.set_extension('authors', default=None, force=True)
author_list = arxiv.df.authors.head(n=100)

for author_doc in author_list:
    ents, authors = clf(author_doc)
    author_doc.ents = ents
    author_doc._.authors = authors
# Out:
# CPU times: user 55.1 s, sys: 791 ms, total: 55.9 s
# Wall time: 28 s

# %%
print('\n'.join(f'{i}:{x._.authors}' for i, x in enumerate(author_list)))
# Out:
# 0:[T. Kosel, I. Grabec]
# 1:[T. Kosel, I. Grabec]
# 2:[Carlos Gershenson]
# 3:[Mohd Abubakr, R.M.Vinay]
# 4:[Jianlin Cheng]
# 5:[Tarik Hadzic, Rune Moller Jensen, Henrik Reif Andersen]
# 6:[Yao HengShuai]
# 7:[Anon Plangprasopchok, Kristina Lerman]
# 8:[Kristina Lerman, Anon Plangprasopchok, Chio Wong]
# 9:[Stefano Bistarelli, Ugo Montanari, Francesca Rossi, Francesco Santini]
# 10:[Juliana S Bernardes, Alberto Davila, Vitor Santos Costa, Gerson
#   Zaverucha]
# 11:[H. Satori, M. Harti, N. Chenfour]
# 12:[H. Satori, M. Harti, N. Chenfour]
# 13:[Giorgio Terracina, Nicola Leone, Vincenzino Lio, Claudio Panetta]
# 14:[Quoc Le, Alexander Smola]
# 15:[Marko A. Rodriguez]
# 16:[Tshilidzi Marwala, Bodie Crossingham]
# 17:[S. Mohamed, D. Rubin, T. Marwala]
# 18:[J. Uglov, V. Schetinin, C. Maple]
# 19:[Walid S. Saba]
# 20:[Christian Gagn\'e, Mich\`ele Sebag, Marc Schoenauer, Marco Tomassini]
# 21:[Andreas Martin Lisewski]
# 22:[Tshilidzi Marwala, Unathi Mahola, Snehashish Chakraverty]
# 23:[Erik Berglund, Joaquin Sitte]
# 24:[Edgar H. de Graaf, Joost N. Kok, Walter A. Kosters]
# 25:[Edgar H. de Graaf, Joost N. Kok, Walter A. Kosters]
# 26:[Evan Hurwitz, Tshilidzi Marwala]
# 27:[Sanjiang Li, Mingsheng Ying]
# 28:[Sujay Sanghavi]
# 29:[Tshilidzi Marwala, Bodie Crossingham]
# 30:[Ishmael S. Msiza, Fulufhelo V. Nelwamondo, Tshilidzi Marwala]
# 31:[F.V. Nelwamondo, T. Marwala]
# 32:[Edgar de Graaf Joost Kok Walter Kosters]
# 33:[E. Habtemariam, T. Marwala, M. Lagazio]
# 34:[Nicolas Godzik, Marc Schoenauer, Mich\`ele Sebag]
# 35:[Alexandre Devert, Nicolas Bred\`eche,
#   Marc Schoenauer]
# 36:[Daegene Song]
# 37:[L. Mdlazi, C.J. Stander, P.S. Heyns, T. Marwala]
# 38:[Camilla Schwind]
# 39:[Alex Graves, Santiago Fernandez, Juergen Schmidhuber]
# 40:[S. Chakraverty, T. Marwala, Pallavi Gupta, Thando Tettey]
# 41:[Tshilidzi Marwala, Thando Tettey, Snehashish Chakraverty]
# 42:[Sizwe M. Dhlamini, Tshilidzi Marwala, Thokozani Majozi]
# 43:[Bradley van Aardt, Tshilidzi Marwala]
# 44:[C.B. Vilakazi, T. Marwala, P. Mautla, E. Moloto]
# 45:[Bodie Crossingham, Tshilidzi Marwala]
# 46:[Sizwe M. Dhlamini, Fulufhelo V. Nelwamondo, Tshilidzi Marwala]
# 47:[Rustem Takhanov]
# 48:[Sgarbas]
# 49:[Lucas Bordeaux, Marco Cadoli, Toni Mancini]
# 50:[Anton Eremeev]
# 51:[Jens Oehlschl\"agel]
# 52:[Bastian Wemmenhove, Bert Kappen]
# 53:[Magnus Boman, Stefan J. Johansson]
# 54:[Marko A. Rodriguez, Johan Bollen]
# 55:[D. A. Sofge]
# 56:[Zhendong Zhao, Lei Yuan, Yuxuan Wang, Forrest Sheng Bao, Shunyi Zhang
#   Yanfei Sun]
# 57:[Krzysztof R. Apt]
# 58:[Amanda Bouffier, Thierry Poibeau]
# 59:[Sylviane R. Schwer]
# 60:[Shane Legg, Marcus Hutter]
# 61:[Khalil Djelloul, Thi-bich-hanh Dao, Thom Fruehwirth]
# 62:[Thierry Hamon, Adeline Nazarenko, Thierry Poibeau, Sophie Aubin, Julien Derivi\`ere]
# 63:[Roy E. Murphy]
# 64:[Ronny Luss, Alexandre d'Aspremont]
# 65:[Onureena Banerjee, Laurent El Ghaoui, Alexandre d'Aspremont]
# 66:[Alexandre d'Aspremont, Francis Bach, Laurent El Ghaoui]
# 67:[Alexandra Bartolo, Patrick C. McGuire, Kenneth P. Camilleri,
#   Christopher Spiteri, Jonathan C. Borg, Philip J. Farrugia, Jens Ormo, Javier
#   Gomez-Elvira, Jose Antonio Rodriguez-Manfredi, Enrique Diaz-Martinez, Helge
#   Ritter, Robert Haschke, Markus Oesker, Joerg Ontrup]
# 68:[Xavier Polanco]
# 69:[Raghav Aras, Alain Dutech, Fran\c{c}ois Charpillet]
# 70:[Gregoire Danoy, Pascal Bouvry, Matthias R. Brust, Enrique Alba]
# 71:[Andrew Schumann, Florentin Smarandache]
# 72:[Chenguang Lu]
# 73:[Wilson Wong]
# 74:[Paolo Liberatore]
# 75:[Ted Pedersen]
# 76:[Stephen Gang Wu, Forrest Sheng Bao, Eric You Xu, Yu-Xuan Wang, Yi-Fan
#   Chang, Qiao-Liang Xiang]
# 77:[Luca Di Gaspero, Andrea Roli]
# 78:[Emanuel Diamant]
# 79:[Marko A. Rodriguez, Johah Bollen, Herbert Van de Sompel]
# 80:[Stasinos Konstantopoulos]
# 81:[Mihai Oltean, Oana Muntean]
# 82:[Walid S. Saba]
# 83:[Oliver Knill, Jose Ramirez-Herran]
# 84:[Oliver Knill, Jose Ramirez-Herran]
# 85:[Oliver Knill, Jose Ramirez-Herran]
# 86:[Paolo Liberatore]
# 87:[Juergen Schmidhuber]
# 88:[Fionn Murtagh]
# 89:[Yasmine B. Sanderson]
# 90:[Florentin Smarandache, Jean Dezert]
# 91:[Juergen Schmidhuber]
# 92:[Cherif Smaili, Maan El Badaoui El Najjar, Fran\c{c}ois Charpillet]
# 93:[Marko A. Rodriguez, Jennifer H. Watkins, Johan Bollen, Carlos
#   Gershenson]
# 94:[Mohsen Bayati, Christian Borgs, Jennifer Chayes, Riccardo Zecchina]
# 95:[Andrea Montanari, Federico Ricci-Tersenghi, Guilhem Semerjian]
# 96:[Paul Fodor]
# 97:[Xinde Li, Xinhan Huang, Florentin Smarandache,
#   Jean Dezert]
# 98:[Andrei Khrennikov]
# 99:[Vukosi N. Marivate, Fulufhelo V. Nelwamodo, Tshilidzi Marwala]

# %% [markdown]
# ## Heuristic check
#
# Let's try to compare which examples NER picks up against our simple heuristic.

# %%
idx = arxiv.indices
with open(files['arxiv'][0]) as fp:
    parsed_authors = pd.DataFrame(load.jsonl(
        fp, 
        transform=lambda dict_: {'authors_parsed': dict_['authors_parsed']} if dict_['id'] in idx else None,
        limit=100
    ))

# %%
parsed_authors
# Out:
#                                        authors_parsed
# 0                     [[Kosel, T., ], [Grabec, I., ]]
# 1                     [[Kosel, T., ], [Grabec, I., ]]
# 2                            [[Gershenson, Carlos, ]]
# 3               [[Abubakr, Mohd, ], [Vinay, R. M., ]]
# 4                                [[Cheng, Jianlin, ]]
# ..                                                ...
# 95  [[Montanari, Andrea, ], [Ricci-Tersenghi, Fede...
# 96                                  [[Fodor, Paul, ]]
# 97  [[Li, Xinde, , ICRL], [Huang, Xinhan, , ICRL],...
# 98                           [[Khrennikov, Andrei, ]]
# 99  [[Marivate, Vukosi N., ], [Nelwamodo, Fulufhel...
#
# [100 rows x 1 columns]

# %%
for i, (a_ner, a_heuristic) in enumerate(zip(author_list, parsed_authors.authors_parsed)):
    if len(a_heuristic) != len(a_ner._.authors):
        print()
        print(i)
        print('Heuristic ::', a_heuristic)
        print(a_ner.text)
        print([f'{x.text} ({x.label_}) //' for x in a_ner.ents])
        print([f'{x} //' for x in a_ner._.authors])

# %% [markdown]
# # Manually compare to heuristics
#
# Based on a quick overview of a subset of the data, seems like we get 100% recall but improve precision (e.g. INRIA, LIPN, etc).

# %%
for i, (a_ner, a_heuristic) in enumerate(zip(author_list, parsed_authors.authors_parsed)):
    print('Transform ::', a_ner._.authors)
    print('Heuristic ::', a_heuristic)
    print()
# Out:
# Transform :: [T. Kosel, I. Grabec]
# Heuristic :: [['Kosel', 'T.', ''], ['Grabec', 'I.', '']]
#
# Transform :: [T. Kosel, I. Grabec]
# Heuristic :: [['Kosel', 'T.', ''], ['Grabec', 'I.', '']]
#
# Transform :: [Carlos Gershenson]
# Heuristic :: [['Gershenson', 'Carlos', '']]
#
# Transform :: [Mohd Abubakr, R.M.Vinay]
# Heuristic :: [['Abubakr', 'Mohd', ''], ['Vinay', 'R. M.', '']]
#
# Transform :: [Jianlin Cheng]
# Heuristic :: [['Cheng', 'Jianlin', '']]
#
# Transform :: [Tarik Hadzic, Rune Moller Jensen, Henrik Reif Andersen]
# Heuristic :: [['Hadzic', 'Tarik', ''], ['Jensen', 'Rune Moller', ''], ['Andersen', 'Henrik Reif', '']]
#
# Transform :: [Yao HengShuai]
# Heuristic :: [['HengShuai', 'Yao', '']]
#
# Transform :: [Anon Plangprasopchok, Kristina Lerman]
# Heuristic :: [['Plangprasopchok', 'Anon', ''], ['Lerman', 'Kristina', '']]
#
# Transform :: [Kristina Lerman, Anon Plangprasopchok, Chio Wong]
# Heuristic :: [['Lerman', 'Kristina', ''], ['Plangprasopchok', 'Anon', ''], ['Wong', 'Chio', '']]
#
# Transform :: [Stefano Bistarelli, Ugo Montanari, Francesca Rossi, Francesco Santini]
# Heuristic :: [['Bistarelli', 'Stefano', ''], ['Montanari', 'Ugo', ''], ['Rossi', 'Francesca', ''], ['Santini', 'Francesco', '']]
#
# Transform :: [Juliana S Bernardes, Alberto Davila, Vitor Santos Costa, Gerson
#   Zaverucha]
# Heuristic :: [['Bernardes', 'Juliana S', ''], ['Davila', 'Alberto', ''], ['Costa', 'Vitor Santos', ''], ['Zaverucha', 'Gerson', '']]
#
# Transform :: [H. Satori, M. Harti, N. Chenfour]
# Heuristic :: [['Satori', 'H.', ''], ['Harti', 'M.', ''], ['Chenfour', 'N.', '']]
#
# Transform :: [H. Satori, M. Harti, N. Chenfour]
# Heuristic :: [['Satori', 'H.', ''], ['Harti', 'M.', ''], ['Chenfour', 'N.', '']]
#
# Transform :: [Giorgio Terracina, Nicola Leone, Vincenzino Lio, Claudio Panetta]
# Heuristic :: [['Terracina', 'Giorgio', ''], ['Leone', 'Nicola', ''], ['Lio', 'Vincenzino', ''], ['Panetta', 'Claudio', '']]
#
# Transform :: [Quoc Le, Alexander Smola]
# Heuristic :: [['Le', 'Quoc', ''], ['Smola', 'Alexander', '']]
#
# Transform :: [Marko A. Rodriguez]
# Heuristic :: [['Rodriguez', 'Marko A.', '']]
#
# Transform :: [Tshilidzi Marwala, Bodie Crossingham]
# Heuristic :: [['Marwala', 'Tshilidzi', ''], ['Crossingham', 'Bodie', '']]
#
# Transform :: [S. Mohamed, D. Rubin, T. Marwala]
# Heuristic :: [['Mohamed', 'S.', ''], ['Rubin', 'D.', ''], ['Marwala', 'T.', '']]
#
# Transform :: [J. Uglov, V. Schetinin, C. Maple]
# Heuristic :: [['Uglov', 'J.', ''], ['Schetinin', 'V.', ''], ['Maple', 'C.', '']]
#
# Transform :: [Walid S. Saba]
# Heuristic :: [['Saba', 'Walid S.', '']]
#
# Transform :: [Christian Gagn\'e, Mich\`ele Sebag, Marc Schoenauer, Marco Tomassini]
# Heuristic :: [['Gagné', 'Christian', '', 'INFORMATIQUE WGZ INC.'], ['Sebag', 'Michèle', '', 'INRIA\n  Futurs'], ['Schoenauer', 'Marc', '', 'INRIA Futurs'], ['Tomassini', 'Marco', '', 'ISI']]
#
# Transform :: [Andreas Martin Lisewski]
# Heuristic :: [['Lisewski', 'Andreas Martin', '']]
#
# Transform :: [Tshilidzi Marwala, Unathi Mahola, Snehashish Chakraverty]
# Heuristic :: [['Marwala', 'Tshilidzi', ''], ['Mahola', 'Unathi', ''], ['Chakraverty', 'Snehashish', '']]
#
# Transform :: [Erik Berglund, Joaquin Sitte]
# Heuristic :: [['Berglund', 'Erik', ''], ['Sitte', 'Joaquin', '']]
#
# Transform :: [Edgar H. de Graaf, Joost N. Kok, Walter A. Kosters]
# Heuristic :: [['de Graaf', 'Edgar H.', ''], ['Kok', 'Joost N.', ''], ['Kosters', 'Walter A.', '']]
#
# Transform :: [Edgar H. de Graaf, Joost N. Kok, Walter A. Kosters]
# Heuristic :: [['de Graaf', 'Edgar H.', ''], ['Kok', 'Joost N.', ''], ['Kosters', 'Walter A.', '']]
#
# Transform :: [Evan Hurwitz, Tshilidzi Marwala]
# Heuristic :: [['Hurwitz', 'Evan', ''], ['Marwala', 'Tshilidzi', '']]
#
# Transform :: [Sanjiang Li, Mingsheng Ying]
# Heuristic :: [['Li', 'Sanjiang', ''], ['Ying', 'Mingsheng', '']]
#
# Transform :: [Sujay Sanghavi]
# Heuristic :: [['Sanghavi', 'Sujay', '']]
#
# Transform :: [Tshilidzi Marwala, Bodie Crossingham]
# Heuristic :: [['Marwala', 'Tshilidzi', ''], ['Crossingham', 'Bodie', '']]
#
# Transform :: [Ishmael S. Msiza, Fulufhelo V. Nelwamondo, Tshilidzi Marwala]
# Heuristic :: [['Msiza', 'Ishmael S.', ''], ['Nelwamondo', 'Fulufhelo V.', ''], ['Marwala', 'Tshilidzi', '']]
#
# Transform :: [F.V. Nelwamondo, T. Marwala]
# Heuristic :: [['Nelwamondo', 'F. V.', ''], ['Marwala', 'T.', '']]
#
# Transform :: [Edgar de Graaf Joost Kok Walter Kosters]
# Heuristic :: [['Kosters', 'Edgar de Graaf Joost Kok Walter', '']]
#
# Transform :: [E. Habtemariam, T. Marwala, M. Lagazio]
# Heuristic :: [['Habtemariam', 'E.', ''], ['Marwala', 'T.', ''], ['Lagazio', 'M.', '']]
#
# Transform :: [Nicolas Godzik, Marc Schoenauer, Mich\`ele Sebag]
# Heuristic :: [['Godzik', 'Nicolas', '', 'INRIA Futurs, INRIA Rocquencourt'], ['Schoenauer', 'Marc', '', 'INRIA Futurs, INRIA Rocquencourt'], ['Sebag', 'Michèle', '', 'INRIA Futurs, LRI']]
#
# Transform :: [Alexandre Devert, Nicolas Bred\`eche,
#   Marc Schoenauer]
# Heuristic :: [['Devert', 'Alexandre', '', 'INRIA Futurs'], ['Bredèche', 'Nicolas', '', 'INRIA Futurs'], ['Schoenauer', 'Marc', '', 'INRIA Futurs']]
#
# Transform :: [Daegene Song]
# Heuristic :: [['Song', 'Daegene', '']]
#
# Transform :: [L. Mdlazi, C.J. Stander, P.S. Heyns, T. Marwala]
# Heuristic :: [['Mdlazi', 'L.', ''], ['Stander', 'C. J.', ''], ['Heyns', 'P. S.', ''], ['Marwala', 'T.', '']]
#
# Transform :: [Camilla Schwind]
# Heuristic :: [['Schwind', 'Camilla', '', 'LIF']]
#
# Transform :: [Alex Graves, Santiago Fernandez, Juergen Schmidhuber]
# Heuristic :: [['Graves', 'Alex', ''], ['Fernandez', 'Santiago', ''], ['Schmidhuber', 'Juergen', '']]
#
# Transform :: [S. Chakraverty, T. Marwala, Pallavi Gupta, Thando Tettey]
# Heuristic :: [['Chakraverty', 'S.', ''], ['Marwala', 'T.', ''], ['Gupta', 'Pallavi', ''], ['Tettey', 'Thando', '']]
#
# Transform :: [Tshilidzi Marwala, Thando Tettey, Snehashish Chakraverty]
# Heuristic :: [['Marwala', 'Tshilidzi', ''], ['Tettey', 'Thando', ''], ['Chakraverty', 'Snehashish', '']]
#
# Transform :: [Sizwe M. Dhlamini, Tshilidzi Marwala, Thokozani Majozi]
# Heuristic :: [['Dhlamini', 'Sizwe M.', ''], ['Marwala', 'Tshilidzi', ''], ['Majozi', 'Thokozani', '']]
#
# Transform :: [Bradley van Aardt, Tshilidzi Marwala]
# Heuristic :: [['van Aardt', 'Bradley', ''], ['Marwala', 'Tshilidzi', '']]
#
# Transform :: [C.B. Vilakazi, T. Marwala, P. Mautla, E. Moloto]
# Heuristic :: [['Vilakazi', 'C. B.', ''], ['Marwala', 'T.', ''], ['Mautla', 'P.', ''], ['Moloto', 'E.', '']]
#
# Transform :: [Bodie Crossingham, Tshilidzi Marwala]
# Heuristic :: [['Crossingham', 'Bodie', ''], ['Marwala', 'Tshilidzi', '']]
#
# Transform :: [Sizwe M. Dhlamini, Fulufhelo V. Nelwamondo, Tshilidzi Marwala]
# Heuristic :: [['Dhlamini*', 'Sizwe M.', ''], ['Nelwamondo**', 'Fulufhelo V.', ''], ['Marwala**', 'Tshilidzi', '']]
#
# Transform :: [Rustem Takhanov]
# Heuristic :: [['Takhanov', 'Rustem', '']]
#
# Transform :: [Sgarbas]
# Heuristic :: [['Sgarbas', 'Kyriakos N.', '']]
#
# Transform :: [Lucas Bordeaux, Marco Cadoli, Toni Mancini]
# Heuristic :: [['Bordeaux', 'Lucas', ''], ['Cadoli', 'Marco', ''], ['Mancini', 'Toni', '']]
#
# Transform :: [Anton Eremeev]
# Heuristic :: [['Eremeev', 'Anton', '']]
#
# Transform :: [Jens Oehlschl\"agel]
# Heuristic :: [['Oehlschlägel', 'Jens', '']]
#
# Transform :: [Bastian Wemmenhove, Bert Kappen]
# Heuristic :: [['Wemmenhove', 'Bastian', ''], ['Kappen', 'Bert', '']]
#
# Transform :: [Magnus Boman, Stefan J. Johansson]
# Heuristic :: [['Boman', 'Magnus', ''], ['Johansson', 'Stefan J.', '']]
#
# Transform :: [Marko A. Rodriguez, Johan Bollen]
# Heuristic :: [['Rodriguez', 'Marko A.', ''], ['Bollen', 'Johan', '']]
#
# Transform :: [D. A. Sofge]
# Heuristic :: [['Sofge', 'D. A.', '']]
#
# Transform :: [Zhendong Zhao, Lei Yuan, Yuxuan Wang, Forrest Sheng Bao, Shunyi Zhang
#   Yanfei Sun]
# Heuristic :: [['Zhao', 'Zhendong', ''], ['Yuan', 'Lei', ''], ['Wang', 'Yuxuan', ''], ['Bao', 'Forrest Sheng', ''], ['Sun', 'Shunyi Zhang Yanfei', '']]
#
# Transform :: [Krzysztof R. Apt]
# Heuristic :: [['Apt', 'Krzysztof R.', '']]
#
# Transform :: [Amanda Bouffier, Thierry Poibeau]
# Heuristic :: [['Bouffier', 'Amanda', '', 'LIPN'], ['Poibeau', 'Thierry', '', 'LIPN']]
#
# Transform :: [Sylviane R. Schwer]
# Heuristic :: [['Schwer', 'Sylviane R.', '', 'LIPN']]
#
# Transform :: [Shane Legg, Marcus Hutter]
# Heuristic :: [['Legg', 'Shane', ''], ['Hutter', 'Marcus', '']]
#
# Transform :: [Khalil Djelloul, Thi-bich-hanh Dao, Thom Fruehwirth]
# Heuristic :: [['Djelloul', 'Khalil', ''], ['Dao', 'Thi-bich-hanh', ''], ['Fruehwirth', 'Thom', '']]
#
# Transform :: [Thierry Hamon, Adeline Nazarenko, Thierry Poibeau, Sophie Aubin, Julien Derivi\`ere]
# Heuristic :: [['Hamon', 'Thierry', '', 'LIPN'], ['Nazarenko', 'Adeline', '', 'LIPN'], ['Poibeau', 'Thierry', '', 'LIPN'], ['Aubin', 'Sophie', '', 'LIPN'], ['Derivière', 'Julien', '', 'LIPN']]
#
# Transform :: [Roy E. Murphy]
# Heuristic :: [['Murphy', 'Roy E.', '']]
#
# Transform :: [Ronny Luss, Alexandre d'Aspremont]
# Heuristic :: [['Luss', 'Ronny', ''], ["d'Aspremont", 'Alexandre', '']]
#
# Transform :: [Onureena Banerjee, Laurent El Ghaoui, Alexandre d'Aspremont]
# Heuristic :: [['Banerjee', 'Onureena', ''], ['Ghaoui', 'Laurent El', ''], ["d'Aspremont", 'Alexandre', '']]
#
# Transform :: [Alexandre d'Aspremont, Francis Bach, Laurent El Ghaoui]
# Heuristic :: [["d'Aspremont", 'Alexandre', ''], ['Bach', 'Francis', ''], ['Ghaoui', 'Laurent El', '']]
#
# Transform :: [Alexandra Bartolo, Patrick C. McGuire, Kenneth P. Camilleri,
#   Christopher Spiteri, Jonathan C. Borg, Philip J. Farrugia, Jens Ormo, Javier
#   Gomez-Elvira, Jose Antonio Rodriguez-Manfredi, Enrique Diaz-Martinez, Helge
#   Ritter, Robert Haschke, Markus Oesker, Joerg Ontrup]
# Heuristic :: [['Bartolo', 'Alexandra', ''], ['McGuire', 'Patrick C.', ''], ['Camilleri', 'Kenneth P.', ''], ['Spiteri', 'Christopher', ''], ['Borg', 'Jonathan C.', ''], ['Farrugia', 'Philip J.', ''], ['Ormo', 'Jens', ''], ['Gomez-Elvira', 'Javier', ''], ['Rodriguez-Manfredi', 'Jose Antonio', ''], ['Diaz-Martinez', 'Enrique', ''], ['Ritter', 'Helge', ''], ['Haschke', 'Robert', ''], ['Oesker', 'Markus', ''], ['Ontrup', 'Joerg', '']]
#
# Transform :: [Xavier Polanco]
# Heuristic :: [['Polanco', 'Xavier', '', 'INIST']]
#
# Transform :: [Raghav Aras, Alain Dutech, Fran\c{c}ois Charpillet]
# Heuristic :: [['Aras', 'Raghav', '', 'INRIA Lorraine - LORIA'], ['Dutech', 'Alain', '', 'INRIA Lorraine -\n  LORIA'], ['Charpillet', 'François', '', 'INRIA Lorraine - LORIA']]
#
# Transform :: [Gregoire Danoy, Pascal Bouvry, Matthias R. Brust, Enrique Alba]
# Heuristic :: [['Danoy', 'Gregoire', ''], ['Bouvry', 'Pascal', ''], ['Brust', 'Matthias R.', ''], ['Alba', 'Enrique', '']]
#
# Transform :: [Andrew Schumann, Florentin Smarandache]
# Heuristic :: [['Schumann', 'Andrew', ''], ['Smarandache', 'Florentin', '']]
#
# Transform :: [Chenguang Lu]
# Heuristic :: [['Lu', 'Chenguang', '']]
#
# Transform :: [Wilson Wong]
# Heuristic :: [['Wong', 'Wilson', '']]
#
# Transform :: [Paolo Liberatore]
# Heuristic :: [['Liberatore', 'Paolo', '']]
#
# Transform :: [Ted Pedersen]
# Heuristic :: [['Pedersen', 'Ted', '']]
#
# Transform :: [Stephen Gang Wu, Forrest Sheng Bao, Eric You Xu, Yu-Xuan Wang, Yi-Fan
#   Chang, Qiao-Liang Xiang]
# Heuristic :: [['Wu', 'Stephen Gang', ''], ['Bao', 'Forrest Sheng', ''], ['Xu', 'Eric You', ''], ['Wang', 'Yu-Xuan', ''], ['Chang', 'Yi-Fan', ''], ['Xiang', 'Qiao-Liang', '']]
#
# Transform :: [Luca Di Gaspero, Andrea Roli]
# Heuristic :: [['Di Gaspero', 'Luca', ''], ['Roli', 'Andrea', '']]
#
# Transform :: [Emanuel Diamant]
# Heuristic :: [['Diamant', 'Emanuel', '']]
#
# Transform :: [Marko A. Rodriguez, Johah Bollen, Herbert Van de Sompel]
# Heuristic :: [['Rodriguez', 'Marko A.', ''], ['Bollen', 'Johah', ''], ['Van de Sompel', 'Herbert', '']]
#
# Transform :: [Stasinos Konstantopoulos]
# Heuristic :: [['Konstantopoulos', 'Stasinos', '']]
#
# Transform :: [Mihai Oltean, Oana Muntean]
# Heuristic :: [['Oltean', 'Mihai', ''], ['Muntean', 'Oana', '']]
#
# Transform :: [Walid S. Saba]
# Heuristic :: [['Saba', 'Walid S.', '']]
#
# Transform :: [Oliver Knill, Jose Ramirez-Herran]
# Heuristic :: [['Knill', 'Oliver', ''], ['Ramirez-Herran', 'Jose', '']]
#
# Transform :: [Oliver Knill, Jose Ramirez-Herran]
# Heuristic :: [['Knill', 'Oliver', ''], ['Ramirez-Herran', 'Jose', '']]
#
# Transform :: [Oliver Knill, Jose Ramirez-Herran]
# Heuristic :: [['Knill', 'Oliver', ''], ['Ramirez-Herran', 'Jose', '']]
#
# Transform :: [Paolo Liberatore]
# Heuristic :: [['Liberatore', 'Paolo', '']]
#
# Transform :: [Juergen Schmidhuber]
# Heuristic :: [['Schmidhuber', 'Juergen', '']]
#
# Transform :: [Fionn Murtagh]
# Heuristic :: [['Murtagh', 'Fionn', '']]
#
# Transform :: [Yasmine B. Sanderson]
# Heuristic :: [['Sanderson', 'Yasmine B.', '']]
#
# Transform :: [Florentin Smarandache, Jean Dezert]
# Heuristic :: [['Smarandache', 'Florentin', ''], ['Dezert', 'Jean', '']]
#
# Transform :: [Juergen Schmidhuber]
# Heuristic :: [['Schmidhuber', 'Juergen', '']]
#
# Transform :: [Cherif Smaili, Maan El Badaoui El Najjar, Fran\c{c}ois Charpillet]
# Heuristic :: [['Smaili', 'Cherif', '', 'INRIA Lorraine - LORIA'], ['Najjar', 'Maan El Badaoui El', '', 'INRIA Lorraine - LORIA'], ['Charpillet', 'François', '', 'INRIA Lorraine - LORIA']]
#
# Transform :: [Marko A. Rodriguez, Jennifer H. Watkins, Johan Bollen, Carlos
#   Gershenson]
# Heuristic :: [['Rodriguez', 'Marko A.', ''], ['Watkins', 'Jennifer H.', ''], ['Bollen', 'Johan', ''], ['Gershenson', 'Carlos', '']]
#
# Transform :: [Mohsen Bayati, Christian Borgs, Jennifer Chayes, Riccardo Zecchina]
# Heuristic :: [['Bayati', 'Mohsen', ''], ['Borgs', 'Christian', ''], ['Chayes', 'Jennifer', ''], ['Zecchina', 'Riccardo', '']]
#
# Transform :: [Andrea Montanari, Federico Ricci-Tersenghi, Guilhem Semerjian]
# Heuristic :: [['Montanari', 'Andrea', ''], ['Ricci-Tersenghi', 'Federico', ''], ['Semerjian', 'Guilhem', '']]
#
# Transform :: [Paul Fodor]
# Heuristic :: [['Fodor', 'Paul', '']]
#
# Transform :: [Xinde Li, Xinhan Huang, Florentin Smarandache,
#   Jean Dezert]
# Heuristic :: [['Li', 'Xinde', '', 'ICRL'], ['Huang', 'Xinhan', '', 'ICRL'], ['Smarandache', 'Florentin', '', 'UNM'], ['Dezert', 'Jean', '', 'ONERA']]
#
# Transform :: [Andrei Khrennikov]
# Heuristic :: [['Khrennikov', 'Andrei', '']]
#
# Transform :: [Vukosi N. Marivate, Fulufhelo V. Nelwamodo, Tshilidzi Marwala]
# Heuristic :: [['Marivate', 'Vukosi N.', ''], ['Nelwamodo', 'Fulufhelo V.', ''], ['Marwala', 'Tshilidzi', '']]
